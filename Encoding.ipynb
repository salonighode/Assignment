# %% [markdown]
# ## Encoding

# %%
Excellent — encoding is the next essential step after cleaning data!

Encoding means transforming categorical or text data into numeric form so that machine learning models can understand it.

Here’s a complete guide 👇

# %% [markdown]
# ## 🧭 Step 1: Identify What Needs Encoding
#
# Categorical features usually come in two types:

# %%
| Type                    | Example                                                | Encoding Method          |
| ----------------------- | ------------------------------------------------------ | ------------------------ |
| **Nominal (no order)**  | Gender = {Male, Female}, City = {Paris, Tokyo, London} | One-Hot Encoding         |
| **Ordinal (has order)** | Size = {Small, Medium, Large}                          | Label / Ordinal Encoding |

# %% [markdown]
# ## 🧩 Step 2: Choose an Encoding Technique
# 🔹 1. Label Encoding (for ordinal data)
#
# Each category gets a unique integer label.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Size'] = le.fit_transform(df['Size'])

# %%
| Size   | Encoded |
| ------ | ------- |
| Small  | 0       |
| Medium | 1       |
| Large  | 2       |

# %%
✅ Good for: Ordinal variables (ordered categories).
⚠️ Avoid for nominal variables — can mislead the model (it may think 2 > 1).

# %%
🔹 2. One-Hot Encoding (for nominal data)

Creates a binary column for each category.

# %%
# Using pandas
df = pd.get_dummies(df, columns=['City'], drop_first=True)

# %%
| City_Paris | City_Tokyo |
| ---------- | ---------- |
| 1          | 0          |
| 0          | 1          |
| 0          | 0          |

# %%
✅ Good for: Nominal variables (no natural order).
⚠️ Can increase dimensionality if there are many categories.

# %%
🔹 3. Ordinal Encoding (custom order)

If categories have a logical order, define it manually.

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder(categories=[['Small', 'Medium', 'Large']])
df[['Size']] = encoder.fit_transform(df[['Size']])

# %%
✅ Keeps order information.
⚠️ Must ensure the order is meaningful.

# %%
🔹 4. Binary Encoding (for high-cardinality features)

Reduces dimensionality by converting categories to binary digits.

# %%
# !pip install category_encoders
import category_encoders as ce

encoder = ce.BinaryEncoder(cols=['Product_ID'])
df = encoder.fit_transform(df)

# %%
✅ Good for: Columns with many unique categories (e.g., zip codes).
⚠️ Slightly less interpretable.

# %%
🔹 5. Target Encoding (Mean Encoding)

Replace each category with the average target value (for supervised learning).

# %%
df['City_encoded'] = df.groupby('City')['Sales'].transform('mean')

# %%
🔹 6. Frequency / Count Encoding

Replace each category with how often it appears.

# %%
df['City_encoded'] = df['City'].map(df['City'].value_counts())

# %%
✅ Simple and effective for tree-based models.
⚠️ Doesn’t capture relationship with the target variable.

# %% [markdown]
# ## 🧠 Step 3: Verify the Encoding
#
# After encoding:

# %%
df.info()
df.head()

# %%
Check:

* All categorical columns are now numeric.

* No unintended high dimensionality.

* Encodings make sense (ordered vs unordered features handled properly).

# %% [markdown]
# ## ⚙️ Step 4: Automate with Scikit-learn Pipelines
#
# To avoid data leakage:

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

categorical_cols = ['City', 'Gender']
numerical_cols = ['Age', 'Income']

preprocessor = ColumnTransformer([
    ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols),
    ('num', 'passthrough', numerical_cols)
])

model = Pipeline(steps=[
    ('preprocess', preprocessor),
    ('classifier', RandomForestClassifier())
])
