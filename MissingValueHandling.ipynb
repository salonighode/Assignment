# %% [markdown]
# ## Handle Missing Values

# %% [markdown]
# Handling missing values is a crucial step in data cleaning and preparation. The right method depends on your data type, the amount of missingness, and the problem context. Here’s a detailed overview of how to handle missing values effectively:

# %% [markdown]
# ## 🧭 Step 1: Identify Missing Values

# %%
import pandas as pd

# Check for missing values
df.isnull().sum()

# Percentage of missing values
df.isnull().mean() * 100

# %% [markdown]
# ## 🧹 Step 2: Understand the Cause
#
# Before deciding how to handle them, determine why the values are missing:
#
# * MCAR (Missing Completely at Random): No pattern. Safe to impute or drop.
#
# * MAR (Missing at Random): Missingness depends on observed data.
#
# * MNAR (Missing Not at Random): Missingness depends on unobserved data — may need modeling or domain knowledge.

# %% [markdown]
# ## Step 3: Choose a Handling Strategy
# 🔹 1. Remove Missing Values
#
# Use this if only a small portion is missing and removal won’t bias the dataset.

# %%
# Remove rows with any missing values
df = df.dropna()

# Remove columns with too many missing values
df = df.dropna(axis=1, thresh=len(df) * 0.6)  # keep columns with ≥60% non-missing

# %%
🔹 2. Imputation (Filling Missing Values)
🔸 Numerical Data:

# Mean / Median / Mode Imputation

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
# or
df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
# KNN Imputer (more advanced)

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=3)
df[['col1','col2']] = imputer.fit_transform(df[['col1','col2']])

# %% [markdown]
#  #Regression Imputation
#
#      Predict missing values using a regression model trained on complete cases.

# %%
#Categorical Data:

         Mode Imputation

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# %%
#'Unknown' Category

# %%
df['City'].fillna('Unknown', inplace=True)

# %%
🔹 3. Model-Based Imputation

Use models (e.g., decision trees, random forests) to predict missing values using other features.
Tools like IterativeImputer in sklearn can automate this:

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imputer = IterativeImputer()
df_imputed = imputer.fit_transform(df)

# %%
🔹 4. Flag Missingness

Add a binary flag column to indicate missingness — sometimes the fact that data is missing is informative:

# %%
df['Age_missing'] = df['Age'].isnull().astype(int)

# %%
🔹 5. Domain-Specific Handling

Sometimes, missing values have a specific meaning (e.g., “No transaction”, “Not applicable”).
In such cases, replace with an appropriate value like 0 or NA_category.

# %% [markdown]
# ## 🧠 Step 4: Validate the Result
#
# After handling missing values:

# %%
df.isnull().sum()

# %%
Check distributions before and after imputation to ensure the data isn’t distorted.
